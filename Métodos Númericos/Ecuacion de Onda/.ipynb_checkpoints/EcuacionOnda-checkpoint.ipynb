# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
L = 1.
nx = 9
dx = L/(nx + 1.)

nt = 20
dt = 0.05
c = 2.
lam = c*dt/dx

# %%
x = np.linspace(0, L, nx+2)
u = np.sin(np.pi*x)

# %%
w = np.empty(nx+2)
w[0] = 0.
w[-1] = 0.
w[1:nx+1] = (1 - lam**2)*u[1:nx+1] + (0.5)*(lam**2)*(u[2:nx+2] + u[0:nx])

# %%
plt.plot(x,w)
plt.title("t=0")
# Out:
# Text(0.5, 1.0, 't=0')

# %%
ut = np.empty(nx+2)

for i in range(1, nt):
    ut[1:nx+1] = 2*(1 - lam**2)*w[1:nx+1] + (lam**2)*(w[2:nx+2] + w[0:nx]) - u[1:nx+1]
    
    plt.plot(x,u)
    plt.title("Evolución")
    
    u = np.copy(w)
    w = np.copy(ut)
