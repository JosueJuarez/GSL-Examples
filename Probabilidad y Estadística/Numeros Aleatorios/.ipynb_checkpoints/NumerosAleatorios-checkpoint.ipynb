# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt

# %%
x = [0]
y = [0]

# %%
for i in range(1,10):
    ang = random.uniform(0, 2*np.pi)
    x.append(x[i-1] + np.cos(ang))
    y.append(y[i-1] + np.sin(ang))

# %%
plt.plot(x,y)
